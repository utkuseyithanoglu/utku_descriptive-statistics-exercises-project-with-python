# %% [markdown]
# # Descriptive Statistics Problems
#
# ## Exercise 1 – How long are movie titles?
#
# In this exercise, you will apply descriptive statistics techniques to a real dataset: a database of 1000 popular movies from the IMDb website.
#
# From the title of each movie, you will:
# - Calculate the title length (in characters).
# - Obtain key statistical metrics: mean, median, mode, range, variance, standard deviation, skewness, and kurtosis.
# - Identify the longest and shortest titles.
# - Visualize the distribution of these lengths with a histogram and a density curve.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, mode
import seaborn as sns
# Load IMDb dataset
url = "../assets/imdb_1000.csv"
df = pd.read_csv(url)
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a new column called 'title_length' with the length (number of characters) of each title
df['title_length']=df['title'].str.len()
"""
title_lengts=[]
for a in df['title']:
    title_lengts.append(len(a))
df['title_length']=title_lengts
"""
df['title_length']
# Out:
# 0      24
# 1      13
# 2      22
# 3      15
# 4      12
#        ..
# 974     7
# 975    27
# 976    47
# 977    11
# 978    11
# Name: title_length, Length: 979, dtype: int64

# %%
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list', 'title_length'],
#       dtype='object')

# %%
# Calculate mean, median, and mode of the 'title_length' column
mu=df['title_length'].mean()
mid=df['title_length'].sort_values().reset_index(drop=True)[len(df['title_length'])//2]
mid=df['title_length'].median()
my_mode=df['title_length'].mode()
mid
# Out:
# np.float64(14.0)

# %%
#titlemaks=df['title_length'].loc[df['title_length'].idxmax()]
#titlemaks
titles=df['title'].loc[df['title_length'].idxmax()]
titles
# Out:
# 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'

# %%
titlemax=df['title_length'].max()
#titlemax
titlemin=df['title_length'].min()
#titlemin
title_range=titlemax-titlemin
stdv=df['title_length'].std()
#stdv
title_var=df['title_length'].var()
#title_var

# %%
# Calculate the range, variance, and standard deviation of 'title_length'
"""
titlemax=df['title_length'].max()
titlemin=df['title_length'].min()
title_range=titlemax-titlemin
stdv=df['title_length'].std()
stdv
#title_var=df['title_length'].var()
#title_var
title_var=((df['title_length'-mu]).sum()/len(df)
title_var
"""
# Out:
# "\ntitlemax=df['title_length'].max()\ntitlemin=df['title_length'].min()\ntitle_range=titlemax-titlemin\nstdv=df['title_length'].std()\nstdv\n#title_var=df['title_length'].var()\n#title_var\ntitle_var=((df['title_length'-mu]).sum()/len(df)\ntitle_var\n"

# %%
# Calculate skewness and kurtosis of the 'title_length' column
title_skew= df['title_length'].skew()
title_skew
title_kurt=df['title_length'].kurt()
title_kurt
# Out:
# np.float64(3.8122887061291544)

# %%
# Print the shortest and longest title based on their length
titles=df['title'].loc[df['title_length'].idxmax()]
titles
short_title=df['title'].loc[df['title_length'].idxmin()]
short_title
# Out:
# 'M'

# %%
# plot your results

d1={
    "my_mean":mu,
    "my_medan":mid,
    "nmode":my_mode,
    "mtitlemax":titlemax,
    "mtitlemin":titlemin,
    "mmyrange":title_range,
    "mtitle_var":title_var,
    "mtitle_skew":title_skew,
    "mtitle_kurt":title_kurt,
       
}

d1=pd.DataFrame(d1)

plt.figure(figsize=(10,9))
sns.barplot(d1,linewidth=2,edgecolor='black',palette="crest")
plt.grid()
plt.title("make_barplot_great_again")
# Out:
# Text(0.5, 1.0, 'make_barplot_great_again')

# %% [markdown]
# ---
#
# ## Exercise 2 – Manual Calculation of Standard Deviation
#
# In this exercise, you will manually calculate the standard deviation by selecting five actual titles from the movie dataset you loaded earlier.

# %%
# Create a list with 5 actual values from df['title_length'], for example: [10, 13, 14, 18, 22]
list1= np.random.choice(df['title_length'],(5))
print(list1)
type(list1)
# Out:
# [25  9 25 20 15]
# numpy.ndarray

# %%
# Calculate the mean of the 5 values
my_mean=list1.mean()
my_mean

# %%
# Calculate the squared differences with respect to the mean
#Ortalama ile olan farkların karesini hesapla
"""
a=[]
for num in df['title_length']:
   a.append(round((num-my_mean)**2,2))
a #bu benim ilk aklıma gelen
"""
#bide kısası varmış o da/ short way to do
#bunu öğren
a=((df['title_length']-my_mean)**2)
a
# Out:
# 0       27.04
# 1       33.64
# 2       10.24
# 3       14.44
# 4       46.24
#         ...
# 974    139.24
# 975     67.24
# 976    795.24
# 977     60.84
# 978     60.84
# Name: title_length, Length: 979, dtype: float64

# %%
# Calculate the variance (average of the squared differences) and its square root to obtain the standard deviation

#first method ve have
#title_var1=df['title_length'].var()
#title_var1
#title_stdv1=df['title_length'].std()
#title_stdv1
#the questin is want to do 2nd way
var1=a.mean()
stdv1=np.sqrt(var1)
stdv1
# Out:
# np.float64(9.113076955873753)
